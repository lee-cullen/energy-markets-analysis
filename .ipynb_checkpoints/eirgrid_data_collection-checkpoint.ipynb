# %%
# Library Import

import pandas as pd
import numpy as np
import requests
import os
import datetime as dt
import requests

# %%
# I have already gathered existing Wind (Forecast & Actual), Demand , Interconnection data. Portal currently allows 
# user to gather data up to 2 months in the past.

# merge the dataframes

merged_df = pd.read_csv("system_demand.csv", parse_dates = ['DATE & TIME'])

work_dir = os.getcwd()

for file in os.listdir(work_dir):
    if file.endswith("tion.csv"):
        df = pd.read_csv(file, parse_dates = ['DATE & TIME'])
        merged_df = pd.merge(merged_df, df, how = 'left', on = ['DATE & TIME'])
        
# Drop & rename irrelevant columns

merged_df = merged_df.drop([' FORECAST DEMAND(MW)', ' REGION_x', ' NET TOTAL(MW)', ' REGION_y'], axis = 1)
cols = merged_df.columns.to_list()
merged_df = merged_df.rename(columns = {cols[0]: 'date_time_bst', cols[1]: 'demand_mw', cols[2]: 'ewic_mw', 
                                        cols[3]: 'moyle_mw',cols[4]: 'generation_mw', cols[5]: 'forecast_wind_mw',
                                        cols[6]: 'actual_wind_mw', cols[7]: 'region'})

merged_df.to_excel('combined_eirgrid_data.xlsx', index = False)

# %%
def get_data(start_day, fund_name):
    """
    Enables user to download data from the portal.
    Requires one argument 'start_day' (int): specifies how far back the user wants to start collecting data
                          'fund_name' (str): specifies the fundamental to be gathered i.e. demandActual, generationActual,
                                             windActual or interconnection
    """
    today = dt.date.today()
    start_date = today - dt.timedelta(days = start_day)
    start_date = dt.datetime.strftime(start_date, "%d-%b-%Y")
    end_date = today - dt.timedelta(days = 1)
    end_date = dt.datetime.strftime(end_date, "%d-%b-%Y")
    
    eirgrid_url = "http://smartgriddashboard.eirgrid.com/DashboardService.svc/csv?area="+fund_name+"&region=ALL&datefrom="+start_date+"%2000:00&dateto="+end_date+"%2023:59"
    
    try:
        r = requests.get(eirgrid_url)
    except Exception as e:
        print("Error acquiring data: %s", str(e))
        return
    
    return r.text

# %%
def process_data():
# Out:
#   File "<ipython-input-60-6033ae7b0f82>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
get_data(7,'demandActual')
# Out:
# 'DATE & TIME, ACTUAL DEMAND(MW), FORECAST DEMAND(MW), REGION\r\n26 October 2019 00:00,3779,-,All Island\r\n26 October 2019 00:15,3768,-,All Island\r\n26 October 2019 00:30,3713,-,All Island\r\n26 October 2019 00:45,3645,-,All Island\r\n26 October 2019 01:00,3578,-,All Island\r\n26 October 2019 01:15,3534,-,All Island\r\n26 October 2019 01:30,3491,-,All Island\r\n26 October 2019 01:45,3435,-,All Island\r\n26 October 2019 02:00,3382,-,All Island\r\n26 October 2019 02:15,3376,-,All Island\r\n26 October 2019 02:30,3337,-,All Island\r\n26 October 2019 02:45,3298,-,All Island\r\n26 October 2019 03:00,3274,-,All Island\r\n26 October 2019 03:15,3264,-,All Island\r\n26 October 2019 03:30,3241,-,All Island\r\n26 October 2019 03:45,3226,-,All Island\r\n26 October 2019 04:00,3219,-,All Island\r\n26 October 2019 04:15,3208,-,All Island\r\n26 October 2019 04:30,3206,-,All Island\r\n26 October 2019 04:45,3214,-,All Island\r\n26 October 2019 05:00,3225,-,All Island\r\n26 October 2019 05:15,3250,-,All Island\r\n26 October 2019 05:30,3257,-,All Island\r\n26 October 2019 05:45,3286,-,All Island\r\n26 October 2019 06:00,3327,-,All Island\r\n26 October 2019 06:15,3413,-,All Island\r\n26 October 2019 06:30,3462,-,All Island\r\n26 October 2019 06:45,3528,-,All Island\r\n26 October 2019 07:00,3612,-,All Island\r\n26 October 2019 07:15,3742,-,All Island\r\n26 October 2019 07:30,3855,-,All Island\r\n26 October 2019 07:45,3967,-,All Island\r\n26 October 2019 08:00,4091,-,All Island\r\n26 October 2019 08:15,4208,-,All Island\r\n26 October 2019 08:30,4305,-,All Island\r\n26 October 2019 08:45,4430,-,All Island\r\n26 October 2019 09:00,4537,-,All Island\r\n26 October 2019 09:15,4575,-,All Island\r\n26 October 2019 09:30,4640,-,All Island\r\n26 October 2019 09:45,4664,-,All Island\r\n26 October 2019 10:00,4768,-,All Island\r\n26 October 2019 10:15,4761,-,All Island\r\n26 October 2019 10:30,4711,-,All Island\r\n26 October 2019 10:45,4692,-,All Island\r\n26 October 2019 11:00,4678,-,All Island\r\n26 October 2019 11:15,4763,-,All Island\r\n26 October 2019 11:30,4767,-,All Island\r\n26 October 2019 11:45,4715,-,All Island\r\n26 October 2019 12:00,4689,-,All Island\r\n26 October 2019 12:15,4662,-,All Island\r\n26 October 2019 12:30,4628,-,All Island\r\n26 October 2019 12:45,4560,-,All Island\r\n26 October 2019 13:00,4543,-,All Island\r\n26 October 2019 13:15,4493,-,All Island\r\n26 October 2019 13:30,4466,-,All Island\r\n26 October 2019 13:45,4345,-,All Island\r\n26 October 2019 14:00,4305,-,All Island\r\n26 October 2019 14:15,4295,-,All Island\r\n26 October 2019 14:30,4268,-,All Island\r\n26 October 2019 14:45,4272,-,All Island\r\n26 October 2019 15:00,4289,-,All Island\r\n26 October 2019 15:15,4285,-,All Island\r\n26 October 2019 15:30,4270,-,All Island\r\n26 October 2019 15:45,4250,-,All Island\r\n26 October 2019 16:00,4254,-,All Island\r\n26 October 2019 16:15,4306,-,All Island\r\n26 October 2019 16:30,4339,-,All Island\r\n26 October 2019 16:45,4432,-,All Island\r\n26 October 2019 17:00,4494,-,All Island\r\n26 October 2019 17:15,4611,-,All Island\r\n26 October 2019 17:30,4651,-,All Island\r\n26 October 2019 17:45,4727,-,All Island\r\n26 October 2019 18:00,4745,-,All Island\r\n26 October 2019 18:15,4810,-,All Island\r\n26 October 2019 18:30,5002,-,All Island\r\n26 October 2019 18:45,5028,-,All Island\r\n26 October 2019 19:00,5014,-,All Island\r\n26 October 2019 19:15,4959,-,All Island\r\n26 October 2019 19:30,4893,-,All Island\r\n26 October 2019 19:45,4834,-,All Island\r\n26 October 2019 20:00,4734,-,All Island\r\n26 October 2019 20:15,4664,-,All Island\r\n26 October 2019 20:30,4613,-,All Island\r\n26 October 2019 20:45,4536,-,All Island\r\n26 October 2019 21:00,4430,-,All Island\r\n26 October 2019 21:15,4361,-,All Island\r\n26 October 2019 21:30,4248,-,All Island\r\n26 October 2019 21:45,4198,-,All Island\r\n26 October 2019 22:00,4108,-,All Island\r\n26 October 2019 22:15,4020,-,All Island\r\n26 October 2019 22:30,3919,-,All Island\r\n26 October 2019 22:45,3 ...
